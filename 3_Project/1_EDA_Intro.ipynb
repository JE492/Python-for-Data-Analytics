# %% [markdown]
# # Initial Load and Clean Data Frame

# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"D:\02_Online lernen Arbeitslaptop 20260321\Luke Barousse\Python for Data Analytics\data_jobs.csv")

df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

#df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

df_DA_US.sample(10)
# Out:
#        job_title_short                                          job_title  \
# 546664    Data Analyst                                       Data Analyst
# 740688    Data Analyst               Healthcare Data Analyst II - Finance
# 291931    Data Analyst                      Healthcare Data SAS Analyst I
# 19493     Data Analyst                              Data Analyst SME Jobs
# 538281    Data Analyst                      Business Systems Data Analyst
# 462719    Data Analyst                             Financial Data Analyst
# 317386    Data Analyst                                  Data Analyst jobs
# 382012    Data Analyst  Client Data Lead Analyst - Express Scripts - H...
# 553180    Data Analyst                              Business Data Analyst
# 524597    Data Analyst                                       Data Analyst
#
#                   job_location                job_via job_schedule_type  \
# 546664              Folsom, CA       via ZipRecruiter         Full-time
# 740688    Rancho Cucamonga, CA             via Indeed         Full-time
# 291931  Jacksonville Beach, FL               via Dice         Full-time
# 19493             Bethesda, MD     via Clearance Jobs        Internship
# 538281        Coral Gables, FL       via ZipRecruiter         Full-time
# 462719      St. Petersburg, FL            via MyKelly         Full-time
# 317386             Chicago, IL  via Jobisty | USA Job         Full-time
# 382012           St. Louis, MO              via Nexxt         Full-time
# 553180                Anywhere        via Robert Half        Contractor
# 524597             Atlanta, GA    via Relocation Jobs         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 546664               False  California, United States 2023-05-04 19:01:17
# 740688               False  California, United States 2023-01-31 21:00:41
# 291931               False                    Georgia 2023-07-14 17:53:57
# 19493                False                    Georgia 2023-11-09 14:36:02
# 538281               False     Florida, United States 2023-01-07 19:01:54
# 462719               False     Florida, United States 2023-03-08 14:01:37
# 317386               False    Illinois, United States 2023-12-12 17:17:48
# 382012               False    Illinois, United States 2023-07-14 18:01:58
# 553180                True                    Georgia 2023-02-07 19:44:58
# 524597               False                    Georgia 2023-04-11 12:52:25
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 546664                  False                  True  United States
# 740688                  False                  True  United States
# 291931                  False                 False  United States
# 19493                   False                  True  United States
# 538281                  False                 False  United States
# 462719                   True                 False  United States
# 317386                  False                 False  United States
# 382012                  False                 False  United States
# 553180                   True                 False  United States
# 524597                  False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 546664         NaN              NaN              NaN
# 740688         NaN              NaN              NaN
# 291931         NaN              NaN              NaN
# 19493          NaN              NaN              NaN
# 538281         NaN              NaN              NaN
# 462719         NaN              NaN              NaN
# 317386         NaN              NaN              NaN
# 382012         NaN              NaN              NaN
# 553180        year         115000.0              NaN
# 524597         NaN              NaN              NaN
#
#                       company_name  \
# 546664                 CTI III LLC
# 740688  Inland Empire Health Plans
# 291931           Ascendo Resources
# 19493                      Peraton
# 538281                   Broadbean
# 462719              Kelly Services
# 317386                Aston Carter
# 382012             The Cigna Group
# 553180                 Robert Half
# 524597       Charger Logistics Inc
#
#                                                job_skills  \
# 546664                 [outlook, word, excel, powerpoint]
# 740688                       [sql, sas, sas, excel, word]
# 291931                            [sas, sas, word, excel]
# 19493   [python, sql, postgresql, oracle, tableau, exc...
# 538281                                        [sql, flow]
# 462719                                              [sql]
# 317386                                            [excel]
# 382012                       [powerpoint, excel, tableau]
# 553180                           [sql, tableau, power bi]
# 524597                                [power bi, tableau]
#
#                                           job_type_skills
# 546664  {'analyst_tools': ['outlook', 'word', 'excel',...
# 740688  {'analyst_tools': ['sas', 'excel', 'word'], 'p...
# 291931  {'analyst_tools': ['sas', 'word', 'excel'], 'p...
# 19493   {'analyst_tools': ['tableau', 'excel'], 'async...
# 538281        {'other': ['flow'], 'programming': ['sql']}
# 462719                           {'programming': ['sql']}
# 317386                       {'analyst_tools': ['excel']}
# 382012  {'analyst_tools': ['powerpoint', 'excel', 'tab...
# 553180  {'analyst_tools': ['tableau', 'power bi'], 'pr...
# 524597         {'analyst_tools': ['power bi', 'tableau']}

# %% [markdown]
# # Filter for Data Analyst Roles

# %%
df_plot = df_DA_US['job_location'].value_counts().head(10).to_frame()

sns.set_theme(style="ticks")
sns.barplot(data=df_plot, x='count', y='job_location', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Job Locations for Data Analysts in the US')
plt.xlabel('Number of Job Postings')
plt.ylabel('')
plt.show()

# %%
fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

dict_column = {
    'job_work_from_home': 'Work from Home',
    'job_no_degree_mention': 'No Degree Mentioned',
    'job_health_insurance': 'Health Insurance Offered'
}

for i, (column, title) in enumerate(dict_column.items()):
    print(i, column, title)
    ax[i].pie(df_DA_US[column].value_counts(), startangle=90, autopct='%1.1f%%', labels=['False', 'True'])
    ax[i].set_title(title)

plt.show()
# Out:
# 0 job_work_from_home Work from Home
# 1 job_no_degree_mention No Degree Mentioned
# 2 job_health_insurance Health Insurance Offered

# %%
df_plot = df_DA_US['company_name'].value_counts().head(10).to_frame()

sns.set_theme(style="ticks")
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Companies for Data Analysts in the US')
plt.xlabel('Number of Job Postings')
plt.ylabel('')
plt.show()
